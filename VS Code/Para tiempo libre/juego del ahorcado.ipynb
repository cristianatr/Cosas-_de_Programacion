# %%
Palabra = ['Pneumonoultramicroscopicsilicovolcanoconiosis','el término utilizado para referirse a la enfermedad pulmonar producida por la intoxicación de sílice','Hipopotomonstrosesquipedaliofobia','miedo irracional (o fobia) a la pronunciación de palabras largas y complicadas','Superescalifragilisticoespialidos','para expresar lo que uno siente cuando te quedas sin palabras','Hexakosioihexekontahexafobia','miedo irracional (o fobia) al número 666','Paralelepípedos','Cuerpo geométrico formado por seis paralelogramos, de los cuales son iguales y paralelos los opuestos entre sí','Esternocleidomastoideo','Músculo que está situado en el cuello y tiene la función de permitir el giro y la inclinación lateral de la cabeza','Homopedonecrozoofílico','sujeto que usa a animales menores, difuntos y de su mismo género para satisfacer sus deseos sexuales','Neotromponolomeonilopolonouta','Tripulante escocés de dicho navío.','Dihidroxifenilalaninasa','Palabra inventada por un biólogo loco que estudiaba la pigmentación de la piel','Ugarterragaicoecheapaturri','Gñap en un idioma raro quizá esperanto.','Metilendioximetanfetamina','Medicamento infantil para la tos','Caravincuntincuadrado','Se dice eso cuando alguien logra la cuadratura del círculo.','Octangolonoplasentaiconósico','Son bichitos con nueve patitas','Linfogranulomatosis','Es cuando te quedas afónic@.']

# %% [markdown]
# # El ahorcado

# %%
import random as rd
 
Nombre =(input('Ingrese su nombre: '))
opcion1 = int(rd.randint(0,13))
PalabraSecreta = Palabra[opcion1]
PalabraSecreta = PalabraSecreta.lower()
opcion2 = int(opcion1 + 1)
pista = Palabra[opcion2]
 
 
 
Errores = 0
Progreso = []
for i in range(len(PalabraSecreta)):
    Progreso.append("_ ")
    PalabraConEspacio = []
    for char in PalabraSecreta:
        PalabraConEspacio.append(char + ' ')
 
    
LetrasUsadas = []
 
print(f'Hola {Nombre} soy el changuito y tengo fe para que me rescates [^-^]')
print(f'\nADVERTENCIA {Nombre}, NO SE PERMITE GOOGLEAR >:V ')
 
while Errores < 7:
  print(f'Tenes {6-Errores} vidas y La pista es: {pista}')
  if Errores == 0:
      #print(f'Hola {Nombre} soy el changuito y tengo fe para que me rescates [^-^]')
      print(' _____ ')
      print(' |   | ')
      print(' |     ')
      print(' |     ')
      print(' |     ')
      print(' |     ')
      print('---    ')
  elif Errores == 1:
      print(' _____ ')
      print(' |   | ')
      print(f' |   o tranki solo es la cabeza ')
      print(' |     ')
      print(' |     ')
      print(' |     ')
      print('---    ')
  elif Errores == 2:
      print(' _____ ')
      print(' |   | ')
      print(f' |   o uhh ')
      print(' |   | ')
      print(' |     ')
      print(' |     ')
      print('---    ')
  elif Errores == 3:
      print(' _____ ')
      print(' |   | ')
      print(f' |   o aun te tengo fe {Nombre}')
      print(' |   | ')
      print(' |  /  ')
      print(' |     ')
      print('---    ')
  elif Errores == 4:
      print(' _____ ')
      print(' |   | ')
      print(' |   o Perdi la fe en vos cuando erraste en la primera')
      print(' |   | ')
      print(' |  | |')
      print(' |     ')
      print('---    ')
  elif Errores == 5:
      print(' _____ ')
      print(' |   | ')
      print(' |   o Ya vali :´v ')
      print(' |  /| ')
      print(' |  | |')
      print(' |     ')
      print('---    ')
  elif Errores == 6:
      print(' _____ ')
      print(' |   | ')
      print(f' |   o confie en vos {Nombre} :c')
      print(' |  /|/')
      print(' |  | |')
      print(' |     ')
      print('---    ')
      print(f'Lo siento {Nombre} pero el changuito murio')
      print('Perdite!!')
      break
  
 
  print(''.join(Progreso))
  print(f'Letras Usadas: {LetrasUsadas}')
  Letra = input('Elija una Letra: ')
  # Verificamos si la letras ingresado por el usuario esta o no
  if Letra in LetrasUsadas:
      print(f'{Nombre} letra ya la usaste...')
 
  else:
      LetrasUsadas.append(Letra)
      HayError = True
 
      for i in range(len(PalabraSecreta)):
          if Letra == PalabraSecreta[i]:
              Progreso[i] = Letra + ' '
              # Si la palabra esta el la lista entonces HayError es falso
              HayError = False
      if HayError:
          Errores += 1
      if PalabraConEspacio == Progreso:
          print(''.join(Progreso))
          print(f'Felicitacion Ganaste {Nombre}')
          break
# Out:
# Hola cristian te tengo fe
#  _____
#  |   |
#  |
#  |
#  |
#  |
# ---
# _ _ _ _ _ _ _ _
# Letras Usadas: []
# Hola cristian te tengo fe
#  _____
#  |   |
#  |
#  |
#  |
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a']
#  _____
#  |   |
#  |   o tranki so es la cabeza
#  |
#  |
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a', 'q']
#  _____
#  |   |
#  |   o uhh
#  |   |
#  |
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a', 'q', 'qw']
#  _____
#  |   |
#  |   o aun te tengo fe cristian
#  |   |
#  |  /
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a', 'q', 'qw', 'l']
#  _____
#  |   |
#  |   o Perdi la fe en vos cuando erraste en la primera
#  |   |
#  |  | |
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a', 'q', 'qw', 'l', '1']
#  _____
#  |   |
#  |   o Ya vali :´v
#  |  /|
#  |  | |
#  |
# ---
# a _ _ _ _ a _ _
# Letras Usadas: ['a', 'q', 'qw', 'l', '1', 'p']
#  _____
#  |   |
#  |   o confie en vos cristian :c
#  |  /|/
#  |  | |
#  |
# ---
# ...

# %% [markdown]
# # El ta-te-ti

# %%
 
def imprimir_tablero(tablero):
    for fila in tablero:
        for i in range(len(fila)):
            if i == len(fila) - 1:
                print(fila[i], end='\n')
            else:
                print(fila[i], end='  ')


def cambiar_tablero(tablero, posicion, jugador):
    if jugador:
        simbolo = 'x'
    else:
        simbolo = 'o'
    
    if posicion == 1:
        if tablero[4][0] == ' ':
            tablero[4][0] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 2:
        if tablero[4][2] == ' ':
            tablero[4][2] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 3:
        if tablero[4][4] == ' ':
            tablero[4][4] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 4:
        if tablero[2][0] == ' ':
            tablero[2][0] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 5:
        if tablero[2][2] == ' ':
            tablero[2][2] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 6:
        if tablero[2][4] == ' ':
            tablero[2][4] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 7:
        if tablero[0][0] == ' ':
            tablero[0][0] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 8:
        if tablero[0][2] == ' ':
            tablero[0][2] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    elif posicion == 9:
        if tablero[0][4] == ' ':
            tablero[0][4] = simbolo
            return 0
        else:
            return 'Esa posicion ya esta ocupada.'
    else:
        return 'Esa posicion no existe.'


def hay_ganador(tablero):
    for simbolo in ['x', 'o']:
        fila_0 = tablero[0][0] == simbolo and tablero[0][2] == simbolo and tablero[0][4] == simbolo
        fila_2 = tablero[2][0] == simbolo and tablero[2][2] == simbolo and tablero[2][4] == simbolo
        fila_4 = tablero[4][0] == simbolo and tablero[4][2] == simbolo and tablero[4][4] == simbolo
        columna_0 = tablero[0][0] == simbolo and tablero[2][0] == simbolo and tablero[4][0] == simbolo
        columna_2 = tablero[0][2] == simbolo and tablero[2][2] == simbolo and tablero[4][2] == simbolo
        columna_4 = tablero[0][4] == simbolo and tablero[2][4] == simbolo and tablero[4][4] == simbolo
        diagonal_abajo = tablero[0][0] == simbolo and tablero[2][2] == simbolo and tablero[4][4] == simbolo
        diagonal_arriba = tablero[4][0] == simbolo and tablero[2][2] == simbolo and tablero[0][4] == simbolo

        if fila_0 or fila_2 or fila_4 or columna_0 or columna_2 or columna_4 or diagonal_abajo or diagonal_arriba:
            if simbolo == 'x':
                return 1
            elif simbolo == 'o':
                return 2
            break


tablero = [
    [' ', '|', ' ', '|', ' '],
    ['-', '+', '-', '+', '-'],
    [' ', '|', ' ', '|', ' '],
    ['-', '+', '-', '+', '-'],
    [' ', '|', ' ', '|', ' ']
]
turno_1 = True
jugador_1 = ''
jugador_2 = ''
turno = 0

imprimir_tablero(tablero)
while turno < 9:
    if jugador_1 == '':
        print('Nombre de jugador 1 (x)')
        jugador_1 = input()
        print('Nombre de jugador 2 (o)')
        jugador_2 = input()
    else:
        if turno_1:
            print(jugador_1 + ', elegi una posicion')
        else:
            print(jugador_2 + ', elegi una posicion')
        
        jugada = int(input())

        valor = cambiar_tablero(tablero, jugada, turno_1)
        if valor == 0:
            turno_1 = not turno_1
            turno += 1
            imprimir_tablero(tablero)
            if hay_ganador(tablero) == 1:
                print(jugador_1 + " gano!")
                break
            elif hay_ganador(tablero) == 2:
                print(jugador_2 + " gano!")
                break
        else:
            print(valor)
        
        if turno == 9:
            print("Empate...")
# Out:
#    |     |
# -  +  -  +  -
#    |     |
# -  +  -  +  -
#    |     |
# Nombre de jugador 1 (x)
# Nombre de jugador 2 (o)
# Nombre de jugador 1 (x)
# Nombre de jugador 2 (o)
# Nombre de jugador 1 (x)
# Nombre de jugador 2 (o)
# a, elegi una posicion
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-182983917c35> in <module>
#     116             print(jugador_2 + ', elegi una posicion')
#     117
# --> 118         jugada = int(input())
#     119
#     120         valor = cambiar_tablero(tablero, jugada, turno_1)
#
# ValueError: invalid literal for int() with base 10: 's'
